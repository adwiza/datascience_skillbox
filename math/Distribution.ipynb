# %%
# %matplotlib inline

import matplotlib.pyplot as plt
from IPython.display import Math, Latex
from IPython.core.display import Image
import seaborn as sns
sns.set(color_codes=True)
sns.set(rc={'figure.figsize':(5,5)})

from scipy.stats import uniform

# %%
n = 10000
start = 10
width = 20
data_uniform = uniform.rvs(size=n, loc=start, scale=width) # формируем случайную выборку с нормальным распределением

# %%
ax = sns.displot(data_uniform, 
                 bins=100,
                 kde=True,
                 color='skyblue')
#                  rug_kws={"linewidth": 15, 'alpha': 1})
ax.set(xlabel='Uniform Distribution ', ylabel='Frequency')

# %% [markdown]
# # Нормальное распределение

# %%
from scipy.stats import norm

# %%
data_normal = norm.rvs(size=10000, loc=0, scale=1)

# %%
ax = sns.displot(data_normal, 
                 bins=100,
                 kde=True,
                 color='skyblue')
#                  rug_kws={"linewidth": 15, 'alpha': 1})
ax.set(xlabel='Normal Distribution ', ylabel='Frequency')

# %% [markdown]
# # Гамма распределение

# %%
from scipy.stats import gamma

# %%
data_gamma = gamma.rvs(a=5, size=10000)

# %%
ax = sns.displot(data_gamma, 
                 bins=100,
                 kde=True,
                 color='skyblue')
#                  rug_kws={"linewidth": 15, 'alpha': 1})
ax.set(xlabel='Gamma Distribution ', ylabel='Frequency')

# %% [markdown]
# # Экспоненциальное распределение

# %%
 from scipy.stats import expon

# %%
data_expon = expon.rvs(scale=1, loc=0, size=1000)

# %%
ax = sns.displot(data_expon, 
                 bins=100,
                 kde=True,
                 color='skyblue')
#                  rug_kws={"linewidth": 15, 'alpha': 1})
ax.set(xlabel='Exponential Distribution ', ylabel='Frequency')

# %% [markdown]
# # Распределение Пуассона

# %%
 from scipy.stats import poisson

# %%
data_poisson = poisson.rvs(mu=3, size=10000)

# %%
ax = sns.displot(data_poisson, 
                 bins=30,
                 kde=True,
                 color='skyblue')
#                  rug_kws={"linewidth": 15, 'alpha': 1})
ax.set(xlabel='Poisson Distribution ', ylabel='Frequency')

# %% [markdown]
# # Биномиальное распределение

# %%
from scipy.stats import binom

# %%
data_binom = binom.rvs(n=10, p=.8, size=10000)

# %%
ax = sns.displot(data_binom, 
                 #bins=30,
                 kde=False,
                 color='skyblue')
#                  rug_kws={"linewidth": 15, 'alpha': 1})
ax.set(xlabel='Binomial Distribution ', ylabel='Frequency')

# %% [markdown]
# # Распределение Бернулли

# %%
from scipy.stats import bernoulli

# %%
data_bernoully = bernoulli.rvs(size=10000, p=.6)

# %%
ax = sns.displot(data_bernoully, 
                 #bins=10,
                 kde=False,
                 color='skyblue')
#                  rug_kws={"linewidth": 15, 'alpha': 1})
ax.set(xlabel='Bernoulli Distribution ', ylabel='Frequency')
