# %%
import csv, json
import numpy as np
import pandas as pd
from elasticsearch import Elasticsearch

es = Elasticsearch(['https://_tableau:password@bi.es.europe-west4.gcp.elastic-cloud.com:443'])
# this returns up to 500 rows, adjust to your needs
# res = es.search(index="purchases-000001", body={"query": {"match": {"title": "elasticsearch"}}}, 500)
# sample = res['hits']['hits']



json_data = es.indices.get(index='purchases-000001') #es.get(index="purchases-000001", id=1)

json_data.raw

json_object = json_data.raw
json_formatted_str = json.dumps(json_object, indent=2)

print(json_formatted_str)
df = pd.read_json(json_formatted_str)

# then open a csv file, and loop through the results, writing to the csv
# with open('outputfile.tsv', 'wb') as csvfile:   
#     filewriter = csv.writer(csvfile, delimiter='\t',  # we use TAB delimited, to handle cases where freeform text may have a comma
#                         quotechar='|', quoting=csv.QUOTE_MINIMAL)
#     # create column header row
#     filewriter.writerow(["column1", "column2", "column3"])    #change the column labels here
#     for hit in sample: 
#         # fill columns 1, 2, 3 with your data 
#         col1 = hit["some"]["deeply"]["nested"]["field"].decode('utf-8') #replace these nested key names with your own
#         col1 = col1.replace('\n', ' ')
#         # col2 = , col3 = , etc...
# Out:
# {
#   "purchases-000001": {
#     "aliases": {
#       "purchases": {}
#     },
#     "mappings": {
#       "dynamic": "strict",
#       "date_detection": false,
#       "properties": {
#         "add_to_cart_event": {
#           "properties": {
#             "diff": {
#               "type": "integer"
#             },
#             "id": {
#               "type": "keyword"
#             },
#             "source": {
#               "type": "keyword"
#             }
#           }
#         },
#         "add_to_cart_sources": {
#           "properties": {
#             "carousel_explore_your_fetish": {
#               "type": "boolean"
#             },
#             "carousel_favourite_studios": {
#               "type": "boolean"
#             },
#             "carousel_recommended_for_you": {
#               "type": "boolean"
#             },
#             "carousel_todays_best": {
#               "type": "boolean"
#             },
#             "clip_page": {
# ...

# %%
response = es.search(
    index='purchases-000001',
#     body={},
#     size=1000
)
# grab list of docs from nested dictionary response
elastic_docs = response["hits"]["hits"]

# %%
elastic_docs
# Out:
# [{'_index': 'purchases-000001',
#   '_id': '276089625',
#   '_score': 1.0,
#   '_source': {'id': 276089625,
#    'timestamp': 1551099561,
#    'category': {'id': 1003, 'name': 'pov fighting'},
#    'clip': {'id': 18717169, 'added_at': 1511803818},
#    'price': {'usd': 10.99},
#    'studio': {'id': 90557,
#     'name': 'Kaidence King - Kinky Klips',
#     'payout': 6.59},
#    'meta': {'processed_at': 1677589188518,
#     'origin_processed_at': 1674693411995},
#    'transaction_id': 55578039,
#    'initial_transaction': {'days_from': 5045, 'timestamp': 1115178712},
#    'previous_transaction': {'days_from': 19},
#    'payment_method': 'sofort'}},
#  {'_index': 'purchases-000001',
#   '_id': '276768337',
#   '_score': 1.0,
#   '_source': {'id': 276768337,
#    'timestamp': 1553344523,
#    'category': {'id': 18, 'name': 'female wrestling'},
#    'clip': {'id': 16718164, 'added_at': 1478988628},
#    'price': {'usd': 8.99},
# ...

# %%
es.cat.count(index="purchases-000001", format="json") # TOTAL records
# Out:
# ListApiResponse([{'epoch': '1691375589', 'timestamp': '02:33:09', 'count': '30889718'}])

# %%
# total num of Elasticsearch documents to get with API call
total_len = 100 #es.cat.count(index="purchases-000001", format="json")


#all_docs = int(total_len[0]['count'])

i = 0
for i in range(total_len):
    total_docs = i
    
    print ("nmaking API call to Elasticsearch for", total_docs, "documents.")
    response = es.search(
        index='purchases-000001',
    #     body={},
        size=total_docs
    )
    # grab list of docs from nested dictionary response
    print ("putting documents in a list")
    elastic_docs = response["hits"]["hits"]

    """
    GET ALL OF THE ELASTICSEARCH
    INDEX'S FIELDS FROM _SOURCE
    """
    #  create an empty Pandas DataFrame object for docs
    data = pd.DataFrame()
    # iterate each Elasticsearch doc in list
    print ("ncreating objects from Elasticsearch data.")
    for num, doc in enumerate(elastic_docs):
        # get _source data dict from document
        source_data = doc["_source"]
        # get _id from document
        _id = doc["_id"]
        # create a Series object from doc dict object
        doc_data = pd.Series(source_data, name = _id)
        # append the Series object to the DataFrame object
        data = data._append(doc_data)
    i += 1
    
# data.set_index('id', inplace=True)
# Out:
# nmaking API call to Elasticsearch for 0 documents.
# putting documents in a list
# ncreating objects from Elasticsearch data.
# nmaking API call to Elasticsearch for 1 documents.
# putting documents in a list
# ncreating objects from Elasticsearch data.
# nmaking API call to Elasticsearch for 2 documents.
# putting documents in a list
# ncreating objects from Elasticsearch data.
# nmaking API call to Elasticsearch for 3 documents.
# putting documents in a list
# ncreating objects from Elasticsearch data.
# nmaking API call to Elasticsearch for 4 documents.
# putting documents in a list
# ncreating objects from Elasticsearch data.
# nmaking API call to Elasticsearch for 5 documents.
# putting documents in a list
# ncreating objects from Elasticsearch data.
# nmaking API call to Elasticsearch for 6 documents.
# putting documents in a list
# ncreating objects from Elasticsearch data.
# nmaking API call to Elasticsearch for 7 documents.
# putting documents in a list
# ...

# %%
# #!/usr/bin/env python3
# #-*- coding: utf-8 -*-
 
# import sys, time, io
# start_time = time.time()
 
# if sys.version[0] != "3":
#     print ("nThis script requires Python 3")
#     print ("Please run the script using the 'python3' command.n")
#     quit()
# try:
#     # import the Elasticsearch low-level client library
#     from elasticsearch import Elasticsearch
#     # import Pandas, JSON, and the NumPy library
#     import pandas, json
#     import numpy as np
# except ImportError as error:
#     print ("nImportError:", error)
#     print ("Please use 'pip3' to install the necessary packages.")
#     quit()
# # create a client instance of the library
# print ("ncreating client instance of Elasticsearch")
 
# """
# MAKE API CALL TO CLUSTER AND CONVERT
# THE RESPONSE OBJECT TO A LIST OF
# ELASTICSEARCH DOCUMENTS
# """
# # total num of Elasticsearch documents to get with API call
# total_len = es.cat.count(index="purchases-000001", format="json")


# all_docs = int(total_len[0]['count'])

# i = 0
# for i in range(all_docs):
#     total_docs = i
    
#     print ("nmaking API call to Elasticsearch for", total_docs, "documents.")
#     response = elastic_client.search(
#         index='purchases-000001',
#     #     body={},
#         size=total_docs
#     )
#     # grab list of docs from nested dictionary response
#     print ("putting documents in a list")
#     elastic_docs = response["hits"]["hits"]

#     """
#     GET ALL OF THE ELASTICSEARCH
#     INDEX'S FIELDS FROM _SOURCE
#     """
#     #  create an empty Pandas DataFrame object for docs
#     docs = pandas.DataFrame()
#     # iterate each Elasticsearch doc in list
#     print ("ncreating objects from Elasticsearch data.")
#     for num, doc in enumerate(elastic_docs):
#         # get _source data dict from document
#         source_data = doc["_source"]
#         # get _id from document
#         _id = doc["_id"]
#         # create a Series object from doc dict object
#         doc_data = pandas.Series(source_data, name = _id)
#         # append the Series object to the DataFrame object
#         docs = docs._append(doc_data)
#     i += 1    

    
 
# """
# EXPORT THE ELASTICSEARCH DOCUMENTS PUT INTO
# PANDAS OBJECTS
# """
# print ("nexporting Pandas objects to different file types.")
 
# # export the Elasticsearch documents as a JSON file
# docs.to_json("objectrocket.json")
# # have Pandas return a JSON string of the documents
# json_export = docs.to_json() # return JSON data
# print ("nJSON data:", json_export)
# # export Elasticsearch documents to a CSV file
# docs.to_csv("objectrocket.csv", ",") # CSV delimited by commas
# # export Elasticsearch documents to CSV
# csv_export = docs.to_csv(sep=",") # CSV delimited by commas
# print ("nCSV data:", csv_export)
# # create IO HTML string
# import io
# html_str = io.StringIO()
# # export as HTML
# docs.to_html(
#     buf=html_str,
#     classes='table table-striped'
# )
 
# # print out the HTML table
# print (html_str.getvalue())
# # save the Elasticsearch documents as an HTML table
# docs.to_html("objectrocket.html")
 
# print ("nntime elapsed:", time.time()-start_time)

# %%
data
# Out:
#                   id   timestamp                                  category
# 276089625  276089625  1551099561      {'id': 1003, 'name': 'pov fighting'}  \
# 276768337  276768337  1553344523    {'id': 18, 'name': 'female wrestling'}
# 276827201  276827201  1553520109           {'id': 79, 'name': 'wrestling'}
# 275583669  275583669  1549428047    {'id': 133, 'name': 'female fighting'}
# 277610107  277610107  1556033149    {'id': 18, 'name': 'female wrestling'}
# ...              ...         ...                                       ...
# 307715315  307715315  1651006702    {'id': 339, 'name': 'mixed wrestling'}
# 284399233  284399233  1578956065         {'id': 11, 'name': 'humiliation'}
# 270410887  270410887  1532475335              {'id': 883, 'name': 'taboo'}
# 270411245  270411245  1532476312  {'id': 123, 'name': 'underwater fetish'}
# 261488345  261488345  1503088335               {'id': 141, 'name': 'milf'}
#
#                                                clip           price
# ...

# %%
facts_table = data.loc[:, ~data.columns.isin(['category', 'clip', 'price', 'studio', 'meta', 
                                              'initial_transaction', 'previous_transaction', 
                                              'customer', 'duplicate_purchase'])]
facts_table
# Out:
#                   id   timestamp  transaction_id payment_method currency
# 276089625  276089625  1551099561        55578039         sofort      NaN  \
# 276768337  276768337  1553344523        55947271         sofort      NaN
# 276827201  276827201  1553520109        55978025         sofort      NaN
# 275583669  275583669  1549428047        55304571         sofort      NaN
# 277610107  277610107  1556033149        56394755         sofort      NaN
# ...              ...         ...             ...            ...      ...
# 307715315  307715315  1651006702        72816909    credit-card      USD
# 284399233  284399233  1578956065        60053751    credit-card      NaN
# 270410887  270410887  1532475335        52509667    credit-card      NaN
# 270411245  270411245  1532476312        52509837    credit-card      NaN
# 261488345  261488345  1503088335        47550097    credit-card      NaN
#
#           oneclick
# 276089625      NaN
# 276768337      NaN
# 276827201      NaN
# ...

# %%
# Separating nested data to different table
nested_data = data[['category', 'clip', 'price', 'studio', 'meta', 'initial_transaction', 'previous_transaction']]

# %%
nested_data
# Out:
#                                            category
# 276089625      {'id': 1003, 'name': 'pov fighting'}  \
# 276768337    {'id': 18, 'name': 'female wrestling'}
# 276827201           {'id': 79, 'name': 'wrestling'}
# 275583669    {'id': 133, 'name': 'female fighting'}
# 277610107    {'id': 18, 'name': 'female wrestling'}
# ...                                             ...
# 307715315    {'id': 339, 'name': 'mixed wrestling'}
# 284399233         {'id': 11, 'name': 'humiliation'}
# 270410887              {'id': 883, 'name': 'taboo'}
# 270411245  {'id': 123, 'name': 'underwater fetish'}
# 261488345               {'id': 141, 'name': 'milf'}
#
#                                                clip           price
# 276089625  {'id': 18717169, 'added_at': 1511803818}  {'usd': 10.99}  \
# 276768337  {'id': 16718164, 'added_at': 1478988628}   {'usd': 8.99}
# 276827201  {'id': 18144456, 'added_at': 1502175605}  {'usd': 13.99}
# ...

# %%
# Created separated tables for each column

# %%
category_table = dict()
for key, value in nested_data.category.items():
    category_table.update({key: value})

# %%
for key in category_table:
    if key not in category_table.values():
        category_table[key].update({'purchase_id': key}) 

category_table = pd.DataFrame(category_table.values())    
category_table
# Out:
#       id               name purchase_id
# 0   1003       pov fighting   276089625
# 1     18   female wrestling   276768337
# 2     79          wrestling   276827201
# 3    133    female fighting   275583669
# 4     18   female wrestling   277610107
# ..   ...                ...         ...
# 94   339    mixed wrestling   307715315
# 95    11        humiliation   284399233
# 96   883              taboo   270410887
# 97   123  underwater fetish   270411245
# 98   141               milf   261488345
#
# [99 rows x 3 columns]

# %%
clip_table = dict()
for key, value in nested_data['clip'].items():
    clip_table.update({key: value})

# %%
for key in clip_table:
    if key not in clip_table.values():
        clip_table[key].update({'purchase_id': key}) 

clip_table = pd.DataFrame(clip_table.values())    
clip_table
# Out:
#           id    added_at purchase_id
# 0   18717169  1511803818   276089625
# 1   16718164  1478988628   276768337
# 2   18144456  1502175605   276827201
# 3   15448733  1459795842   275583669
# 4   21182721  1552595793   277610107
# ..       ...         ...         ...
# 94  18856215  1513876528   307715315
# 95  20469925  1540305185   284399233
# 96  19957715  1531698613   270410887
# 97  19672577  1526860854   270411245
# 98  17930430  1498801414   261488345
#
# [99 rows x 3 columns]

# %%
price_table = dict()
for key, value in nested_data['price'].items():
    price_table.update({key: value})

# %%
for key in price_table:
    if key not in price_table.values():
        price_table[key].update({'purchase_id': key}) 

price_table = pd.DataFrame(price_table.values())    
price_table
# Out:
#       usd purchase_id
# 0   10.99   276089625
# 1    8.99   276768337
# 2   13.99   276827201
# 3    7.99   275583669
# 4   23.99   277610107
# ..    ...         ...
# 94  12.99   307715315
# 95  10.99   284399233
# 96  21.99   270410887
# 97  10.99   270411245
# 98  19.99   261488345
#
# [99 rows x 2 columns]

# %%
# print number of documents
print ("documents returned:", len(response["hits"]["hits"]))
# Out:
# documents returned: 99

# %%
# iterate over all of the docs (use iteritems() in Python 2)
for key, val in response["hits"].items():
    if key == "hits":
        for num, doc in enumerate(val):
            print (num, '-->', doc, "\n")
# Out:
# 0 --> {'_index': 'purchases-000001', '_id': '276089625', '_score': 1.0, '_source': {'id': 276089625, 'timestamp': 1551099561, 'category': {'id': 1003, 'name': 'pov fighting', 'purchase_id': '276089625'}, 'clip': {'id': 18717169, 'added_at': 1511803818, 'purchase_id': '276089625'}, 'price': {'usd': 10.99, 'purchase_id': '276089625'}, 'studio': {'id': 90557, 'name': 'Kaidence King - Kinky Klips', 'payout': 6.59}, 'meta': {'processed_at': 1677589188518, 'origin_processed_at': 1674693411995}, 'transaction_id': 55578039, 'initial_transaction': {'days_from': 5045, 'timestamp': 1115178712}, 'previous_transaction': {'days_from': 19}, 'payment_method': 'sofort'}}
#
# ...

# %%
data = response["hits"]["hits"]
fields = {}
for num, doc in enumerate(data):
    # get source data from document
    source_data = doc["_source"]

# %%
    # iterate source data (use iteritems() for Python 2)
    for key, val in source_data.items():
        try:
            fields[key] = np.append(fields[key], val)
        except KeyError:
            fields[key] = np.array([val])

# %%
for key, val in fields.items():
    print (key, "--->", val)
    print ("NumPy array len:", len(val), "\n")
# Out:
# id ---> [261488345]
# NumPy array len: 1
#
# timestamp ---> [1503088335]
# NumPy array len: 1
#
# category ---> [{'id': 141, 'name': 'milf', 'purchase_id': '261488345'}]
# NumPy array len: 1
#
# clip ---> [{'id': 17930430, 'added_at': 1498801414, 'purchase_id': '261488345'}]
# NumPy array len: 1
#
# customer ---> [{'id': 463684, 'email': 'jarvineno@gmail.com', 'country': 'FI', 'logged_in': True}]
# NumPy array len: 1
#
# price ---> [{'usd': 19.99, 'purchase_id': '261488345'}]
# NumPy array len: 1
#
# studio ---> [{'id': 79477, 'name': 'Natalie Wonder Clips', 'payout': 11.99}]
# NumPy array len: 1
#
# meta ---> [{'processed_at': 1678566031800, 'origin_processed_at': 1678565708493}]
# NumPy array len: 1
#
# transaction_id ---> [47550097]
# NumPy array len: 1
#
# initial_transaction ---> [{'days_from': 1204, 'timestamp': 1399046830}]
# NumPy array len: 1
#
# previous_transaction ---> [{'days_from': 2}]
# NumPy array len: 1
#
# payment_method ---> ['credit-card']
# NumPy array len: 1

# %%
# create a Pandas DataFrame array from the fields dict
elastic_df = pd.DataFrame(fields)

print('elastic_df:', type(elastic_df), "\n")
print(elastic_df) # print out the DF object's contents
# Out:
# elastic_df: <class 'pandas.core.frame.DataFrame'>
#
#           id   timestamp                                           category
# 0  261488345  1503088335  {'id': 141, 'name': 'milf', 'purchase_id': '26...  \
#
#                                                 clip
# 0  {'id': 17930430, 'added_at': 1498801414, 'purc...  \
#
#                                             customer
# 0  {'id': 463684, 'email': 'jarvineno@gmail.com',...  \
#
#                                         price
# 0  {'usd': 19.99, 'purchase_id': '261488345'}  \
#
#                                               studio
# 0  {'id': 79477, 'name': 'Natalie Wonder Clips', ...  \
#
#                                                 meta  transaction_id
# 0  {'processed_at': 1678566031800, 'origin_proces...        47550097  \
#
#                             initial_transaction previous_transaction
# 0  {'days_from': 1204, 'timestamp': 1399046830}     {'days_from': 2}  \
#
#   payment_method
# 0    credit-card

# %%
# create a JSON string from the Pandas object
json_data = elastic_df.to_json()
print ("\nto_json() method:", json_data)
# Out:
# to_json() method: {"id":{"0":261488345},"timestamp":{"0":1503088335},"category":{"0":{"id":141,"name":"milf","purchase_id":"261488345"}},"clip":{"0":{"id":17930430,"added_at":1498801414,"purchase_id":"261488345"}},"customer":{"0":{"id":463684,"email":"jarvineno@gmail.com","country":"FI","logged_in":true}},"price":{"0":{"usd":19.99,"purchase_id":"261488345"}},"studio":{"0":{"id":79477,"name":"Natalie Wonder Clips","payout":11.99}},"meta":{"0":{"processed_at":1678566031800,"origin_processed_at":1678565708493}},"transaction_id":{"0":47550097},"initial_transaction":{"0":{"days_from":1204,"timestamp":1399046830}},"previous_transaction":{"0":{"days_from":2}},"payment_method":{"0":"credit-card"}}

# %%
# verify that the to_json() method made a JSON string
try:
    json.loads(json_data)
    print ("\njson_data is a valid JSON string")
except json.decoder.JSONDecodeError as err:
    print ("\njson.decoder.JSONDecodeError:", err)
    print ("json_data is NOT a valid JSON string")
# Out:
# json_data is a valid JSON string

# %%
# create an empty dict for series arrays
elastic_series = {}

# %%
# iterate the docs returned by API call
for num, doc in enumerate(elastic_docs):

    # get the _id for the doc
    _id = doc["_id"]

    # get source data from document
    source_data = doc["_source"]

    # make a Pandas Series object for the doc using _id as key
    elastic_series[_id] = pd.Series()

    # iterate source data (use iteritems() for Python 2)
    for field, value in source_data.items():

        # set the field type as Series index and value as Series val
        elastic_series[_id].at[field] = value

# %%
for key, doc in elastic_series.items():
    print ("\nID:", key, "\n", doc)
# Out:
# ID: 276089625
#  id                                                              276089625
# timestamp                                                      1551099561
# category                {'id': 1003, 'name': 'pov fighting', 'purchase...
# clip                    {'id': 18717169, 'added_at': 1511803818, 'purc...
# price                          {'usd': 10.99, 'purchase_id': '276089625'}
# studio                  {'id': 90557, 'name': 'Kaidence King - Kinky K...
# meta                    {'processed_at': 1677589188518, 'origin_proces...
# transaction_id                                                   55578039
# initial_transaction          {'days_from': 5045, 'timestamp': 1115178712}
# previous_transaction                                    {'days_from': 19}
# payment_method                                                     sofort
# dtype: object
#
# ID: 276768337
#  id                                                              276768337
# ...
