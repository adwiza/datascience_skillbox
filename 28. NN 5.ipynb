# %%
# загрузим данные
! wget https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv -P datasets/
import pandas as pd

dataset = pd.read_csv("datasets/pima-indians-diabetes.data.csv", header=None)
dataset.columns = ["number_times_pregnant",
"plasma_glucose_concent","blood_pressure",
"skin_thickness", "insulin", "BMI", "diabetes_pedigree", "age", "has_diabetes"]
dataset.head()
# Out:
# --2023-04-02 12:57:39--  https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv
# Распознаётся raw.githubusercontent.com (raw.githubusercontent.com)… 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# Подключение к raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... соединение установлено.
# HTTP-запрос отправлен. Ожидание ответа… 200 OK
# Длина: 23278 (23K) [text/plain]
# Сохранение в: «datasets/pima-indians-diabetes.data.csv.2»
#
# pima-indians-diabet 100%[===================>]  22,73K  --.-KB/s    за 0,001s
#
# 2023-04-02 12:57:40 (26,6 MB/s) - «datasets/pima-indians-diabetes.data.csv.2» сохранён [23278/23278]
#    number_times_pregnant  plasma_glucose_concent  blood_pressure  \
# 0                      6                     148              72
# 1                      1                      85              66
# 2                      8                     183              64
# 3                      1                      89              66
# 4                      0                     137              40
#
#    skin_thickness  insulin   BMI  diabetes_pedigree  age  has_diabetes
# 0              35        0  33.6              0.627   50             1
# 1              29        0  26.6              0.351   31             0
# 2               0        0  23.3              0.672   32             1
# 3              23       94  28.1              0.167   21             0
# 4              35      168  43.1              2.288   33             1

# %%
import numpy as np
from sklearn.model_selection import train_test_split

np.random.seed(10)

X = dataset.drop(['has_diabetes'], axis=1).values
y = dataset['has_diabetes'].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2)
print(f'Train shape: {X_train.shape}, Test_shape: {X_test.shape}, Labels ratio: {y_train.mean():.2f}')
# Out:
# Train shape: (614, 8), Test_shape: (154, 8), Labels ratio: 0.34

# %%
import tensorflow as tf
import numpy as np
# Out:
# 2023-04-02 12:57:42.903507: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def get_compiled_model():
    """
    The function returns compiled model for the binary classification
    """
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Dense(24, input_dim=8, activation='relu'))
    model.add(tf.keras.layers.Dense(24, activation='relu'))
    model.add(tf.keras.layers.Dense(24, activation='relu'))
    model.add(tf.keras.layers.Dense(1, activation='sigmoid'))
    
    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-2)
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    
    return model

model = get_compiled_model()
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=150, batch_size=64, verbose=1)
# Out:
# 2023-04-02 12:57:49.849231: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/150
# 10/10 [==============================] - 1s 39ms/step - loss: 5.1528 - accuracy: 0.4984 - val_loss: 2.0735 - val_accuracy: 0.6234
# Epoch 2/150
# 10/10 [==============================] - 0s 5ms/step - loss: 1.3533 - accuracy: 0.5896 - val_loss: 0.8250 - val_accuracy: 0.6104
# Epoch 3/150
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7622 - accuracy: 0.5945 - val_loss: 0.6680 - val_accuracy: 0.6169
# Epoch 4/150
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6787 - accuracy: 0.6287 - val_loss: 0.6415 - val_accuracy: 0.6494
# Epoch 5/150
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6450 - accuracy: 0.6531 - val_loss: 0.7212 - val_accuracy: 0.6494
# Epoch 6/150
# 10/10 [==============================] - 0s 8ms/step - loss: 0.6218 - accuracy: 0.6808 - val_loss: 0.6377 - val_accuracy: 0.6818
# Epoch 7/150
# 10/10 [==============================] - 0s 8ms/step - loss: 0.5959 - accuracy: 0.6938 - val_loss: 0.7204 - val_accuracy: 0.6429
# Epoch 8/150
# 10/10 [==============================] - 0s 6ms/step - loss: 0.
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4587 - accuracy: 0.7752 - val_loss: 0.5326 - val_accuracy: 0.7208

# %% [markdown]
# ### Сохранение модели
#
# За запись чекпоинтов в keras отвечает **tf.keras.callbacks.ModelCheckpoint**. Как видно из пути к модулю -- он относится к коллбекам (callbacks). Можно смотреть на них как на функции, которые вызывает метод model.fit внутри себя.
#
# То есть каждый раз, когда отработает одна из эпох цикла, будет запускаться функция, которую мы укажем. Бывают коллбеки, которые вызываются на каждой итерации (например [прогресс бар](https://keras.io/callbacks/#progbarlogger), который мы видим при обучении -- это тоже коллбэк). Чуть ниже мы разберем конкретный пример.
#
# Вернемся к **tf.keras.callbacks.ModelCheckpoint**.
#
# ```
# tf.keras.callbacks.ModelCheckpoint(filepath, monitor='val_loss', verbose=0, save_best_only=False, save_weights_only=False, mode='auto', ...)
# ```
#
# Он имеет один обязательный параметр -- имя чекпоинта. Оно может быть отформатировано с использованием служебных переменных (пример ниже). Из необязательных, но полезных параметров:
#
# *   monitor (str): название метрики за которой нужно "следить"
# *   verbose -- печатать ли дополнительную информацию
# *   save_best_only (bool): сохранять чекпоинт только после улучшения метрики, указанной в monitor
# *   save_weights_only (bool): помимо весов модели можно еще сохранять ее архитектуру и состояние оптимизатора. В примерах мы так и будем делать, если не сказано обратное. По умолчанию -- false.
# *   mode (str): если метрику нужно максимизировать -- max, иначе -- min.
#
#
# **Таким образом, если выбрано save_best_only, то чекпоинты будут сохранятся только после тех эпох, когда произошло улучшение метрики, которую мы указали в monitor. Т.к. понятие "лучше" -- разное для разных метрик, необходимо также указать режим -- max/min (больше -- лучше/меньше -- лучше). Пример таких метрик -- лосс (min) и точность (max)**.

# %%
from pathlib import Path
path = Path('models/model_1.model')
path.mkdir(exist_ok=True) 
cpt_filename = '{epoch:02d}_checkpoint_{val_loss:.2f}.hdf5'
cpt_path = str(path / cpt_filename)

checkpoint = tf.keras.callbacks.ModelCheckpoint(cpt_path, monitor='val_loss', verbose=1, 
                                                save_best_only=True, mode='min')

# %%
for epoch in range(4):
    print(cpt_path.format(epoch=epoch, val_loss=np.random.rand()))
# Out:
# models/model_1.model/00_checkpoint_0.38.hdf5
# models/model_1.model/01_checkpoint_0.67.hdf5
# models/model_1.model/02_checkpoint_0.39.hdf5
# models/model_1.model/03_checkpoint_0.22.hdf5

# %% [markdown]
# Мы используем hdf5 -- основной формат для keras. Для Tensorflow -- это ckpt. Сохранять в этом расширении можно аналогичным образом. Подробнее можно прочитать [здесь](https://www.tensorflow.org/tutorials/keras/save_and_restore_models).

# %%
model = get_compiled_model()
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=150, batch_size=64, verbose=0, 
          callbacks=[checkpoint])
# Out:
# Epoch 1: val_loss improved from inf to 0.87505, saving model to models/model_1.model/01_checkpoint_0.88.hdf5
#
# Epoch 2: val_loss did not improve from 0.87505
#
# Epoch 3: val_loss improved from 0.87505 to 0.74202, saving model to models/model_1.model/03_checkpoint_0.74.hdf5
#
# Epoch 4: val_loss improved from 0.74202 to 0.73429, saving model to models/model_1.model/04_checkpoint_0.73.hdf5
#
# Epoch 5: val_loss improved from 0.73429 to 0.63223, saving model to models/model_1.model/05_checkpoint_0.63.hdf5
#
# Epoch 6: val_loss did not improve from 0.63223
#
# Epoch 7: val_loss did not improve from 0.63223
#
# Epoch 8: val_loss did not improve from 0.63223
#
# Epoch 9: val_loss improved from 0.63223 to 0.60587, saving model to models/model_1.model/09_checkpoint_0.61.hdf5
#
# Epoch 10: val_loss did not improve from 0.60587
#
# Epoch 11: val_loss did not improve from 0.60587
#
# Epoch 12: val_loss did not improve from 0.60587
#
# Epoch 13: val_loss did not improve from 0.60587
#
# Epoch 14: val_loss did not improve from 0.60587
#
# Epoch 15: val_loss did not improve from 0.60587
#
# Epoch 16: val_loss did not improve from 0.60587
#
# Epoch 17: val_loss did not improve from 0.60587
#
# Epoch 18: val_loss did not improve from 0.60587
#
# Epoch 19: val_loss improved from 0.60587 to 0.59387, saving model to models/model_1.model/19_checkpoint_0.59.hdf5
#
# Epoch 20: val_loss did not improve from 0.59387
#
# Epoch 21: val_loss did not improve from 0.59387
#
# Epoch 22: val_loss did not improve from 0.59387
#
# Epoch 23: val_loss did not improve from 0.59387
#
# Epoch 24: val_loss did not improve from 0.59387
#
# Epoch 25: val_loss did not improve from 0.59387
#
# Epoch 26: val_loss did not improve from 0.59387
#
# Epoch 27: val_loss did not improve from 0.59387
#
# Epoch 28: val_loss improved from 0.59387 to 0.55806, saving model to models/model_1.model/28_checkpoint_0.56.hdf5
#
# Epoch 29: val_loss did not improve from 0.55806
#
# Epoch 30: val_loss did not improve from 0.55806
#
# Epoch 31: val_loss did not improve from 0.55806
#
# Epoch 32: val_loss did not improve from 0.55806
#
# Epoch 33: val_loss did not improve from 0.55806
#
# Epoch 34: val_loss did not improve from 0.55806
#
# Epoch 35: val_loss did not improve from 0.55806
#
# Epoch 36: val_loss did not improve from 0.55806
#
# Epoch 37: val_loss did not improve from 0.55806
#
# Epoch 38: val_loss did not improve from 0.55806
#
# Epoch 39: val_loss did not improve from 0.55806
#
# Epoch 40: val_loss did not improve from 0.55806
#
# Epoch 41: val_loss did not improve from 0.55806
#
# Epoch 42: val_loss did not improve from 0.55806
#
# Epoch 43: val_loss did not improve from 0.55806
#
# Epoch 44: val_loss did not improve from 0.55806
#
# Epoch 45: val_loss did not improve from 0.55806
#
# Epoch 46: val_loss did not improve from 0.55806
#
# Epoch 47: val_loss did not improve from 0.55806
#
# Epoch 48: val_loss did not improve from 0.55806
#
# Epoch 49: val_loss did not improve from 0.55806
#
# Epoch 50: val_loss did not improve from 0.55806
#
# Epoch 51: val_loss did not improve from 0.55806
#
# Epoch 52: val_loss did not improve from 0.55806
#
# Epoch 53: val_loss did not improve from 0.55806
#
# Epoch 54: val_loss did not improve from 0.55806
#
# Epoch 55: val_loss did not improve from 0.55806
#
# Epoch 56: val_loss did not improve from 0.55806
#
# Epoch 57: val_loss did not improve from 0.55806
#
# Epoch 58: val_loss did not improve from 0.55806
#
# Epoch 59: val_loss did not improve from 0.55806
#
# Epoch 60: val_loss did not improve from 0.55806
#
# Epoch 61: val_loss did not improve from 0.55806
#
# Epoch 62: val_loss did not improve from 0.55806
#
# Epoch 63: val_loss did not improve from 0.55806
#
# Epoch 64: val_loss did not improve from 0.55806
#
# Epoch 65: val_loss did not improve from 0.55806
#
# Epoch 66: val_loss did not improve from 0.55806
#
# Epoch 67: val_loss did not improve from 0.55806
#
# Epoch 68: val_loss did not improve from 0.55806
#
# Epoch 69: val_loss did not improve from 0.55806
#
# Epoch 70: val_loss did not improve from 0.55806
#
# Epoch 71: val_loss did not improve from 0.55806
#
# Epoch 72: val_loss did not improve from 0.55806
#
# Epoch 73: val_loss did not improve from 0.55806
#
# Epoch 74: val_loss did not improve from 0.55806
#
# Epoch 75: val_loss did not improve from 0.55806
#
# Epoch 76: val_loss did not improve from 0.55806
#
# Epoch 77: val_loss did not improve from 0.55806
#
# Epoch 78: val_loss did not improve from 0.55806
#
# Epoch 79: val_loss did not improve from 0.55806
#
# Epoch 80: val_loss did not improve from 0.55806
#
# Epoch 81: val_loss did not improve from 0.55806
#
# Epoch 82: val_loss did not improve from 0.55806
#
# Epoch 83: val_loss did not improve from 0.55806
#
# Epoch 84: val_loss did not improve from 0.55806
#
# Epoch 85: val_loss did not improve from 0.55806
#
# Epoch 86: val_loss did not improve from 0.55806
#
# Epoch 87: val_loss did not improve from 0.55806
#
# Epoch 88: val_loss did not improve from 0.55806
#
# Epoch 89: val_loss did not improve from 0.55806
#
# Epoch 90: val_loss did not improve from 0.55806
#
# Epoch 91: val_loss did not improve from 0.55806
#
# Epoch 92: val_loss did not improve from 0.55806
#
# Epoch 93: val_loss did not improve from 0.55806
#
# Epoch 94: val_loss did not improve from 0.55806
#
# Epoch 95: val_loss did not improve from 0.55806
#
# Epoch 96: val_loss improved from 0.55806 to 0.55167, saving model to models/model_1.model/96_checkpoint_0.55.hdf5
#
# Epoch 97: val_loss did not improve from 0.55167
#
# Epoch 98: val_loss did not improve from 0.55167
#
# Epoch 99: val_loss did not improve from 0.55167
#
# Epoch 100: val_loss did not improve from 0.55167
#
# Epoch 101: val_loss did not improve from 0.55167
#
# Epoch 102: val_loss did not improve from 0.55167
#
# Epoch 103: val_loss did not improve from 0.55167
#
# Epoch 104: val_loss did not improve from 0.55167
#
# Epoch 105: val_loss did not improve from 0.55167
#
# Epoch 106: val_loss did not improve from 0.55167
#
# Epoch 107: val_loss did not improve from 0.55167
#
# Epoch 108: val_loss did not improve from 0.55167
#
# Epoch 109: val_loss did not improve from 0.55167
#
# Epoch 110: val_loss did not improve from 0.55167
#
# Epoch 111: val_loss did not improve from 0.55167
#
# Epoch 112: val_loss did not improve from 0.55167
#
# Epoch 113: val_loss did not improve from 0.55167
#
# Epoch 114: val_loss did not improve from 0.55167
#
# Epoch 115: val_loss did not improve from 0.55167
#
# Epoch 116: val_loss did not improve from 0.55167
#
# Epoch 117: val_loss did not improve from 0.55167
#
# Epoch 118: val_loss did not improve from 0.55167
#
# Epoch 119: val_loss did not improve from 0.55167
#
# Epoch 120: val_loss did not improve from 0.55167
#
# Epoch 121: val_loss did not improve from 0.55167
#
# Epoch 122: val_loss did not improve from 0.55167
#
# Epoch 123: val_loss did not improve from 0.55167
#
# Epoch 124: val_loss did not improve from 0.55167
#
# Epoch 125: val_loss did not improve from 0.55167
#
# Epoch 126: val_loss did not improve from 0.55167
#
# Epoch 127: val_loss did not improve from 0.55167
#
# Epoch 128: val_loss did not improve from 0.55167
#
# Epoch 129: val_loss did not improve from 0.55167
#
# Epoch 130: val_loss did not improve from 0.55167
#
# Epoch 131: val_loss did not improve from 0.55167
#
# Epoch 132: val_loss did not improve from 0.55167
#
# Epoch 133: val_loss did not improve from 0.55167
#
# Epoch 134: val_loss did not improve from 0.55167
#
# Epoch 135: val_loss did not improve from 0.55167
#
# Epoch 136: val_loss did not improve from 0.55167
#
# Epoch 137: val_loss did not improve from 0.55167
#
# Epoch 138: val_loss did not improve from 0.55167
#
# Epoch 139: val_loss did not improve from 0.55167
#
# Epoch 140: val_loss did not improve from 0.55167
#
# Epoch 141: val_loss did not improve from 0.55167
#
# Epoch 142: val_loss did not improve from 0.55167
#
# Epoch 143: val_loss did not improve from 0.55167
#
# Epoch 144: val_loss did not improve from 0.55167
#
# Epoch 145: val_loss did not improve from 0.55167
#
# Epoch 146: val_loss did not improve from 0.55167
#
# Epoch 147: val_loss did not improve from 0.55167
#
# Epoch 148: val_loss did not improve from 0.55167
#
# Epoch 149: val_loss did not improve from 0.55167
#
# Epoch 150: val_loss did not improve from 0.55167

# %%
! ls 'models/model_1.model/'
# Out:
# 01_checkpoint_0.88.hdf5  08_checkpoint_0.62.hdf5  25_checkpoint_0.58.hdf5
# 02_checkpoint_0.63.hdf5  09_checkpoint_0.61.hdf5  28_checkpoint_0.56.hdf5
# 03_checkpoint_0.74.hdf5  126_checkpoint_0.53.hdf5 33_checkpoint_0.56.hdf5
# 04_checkpoint_0.73.hdf5  139_checkpoint_0.52.hdf5 57_checkpoint_0.54.hdf5
# 05_checkpoint_0.63.hdf5  18_checkpoint_0.60.hdf5  96_checkpoint_0.55.hdf5
# 07_checkpoint_0.62.hdf5  19_checkpoint_0.59.hdf5

# %% [markdown]
# # Model loading

# %% [markdown]
# Загрузить модель можно двумя способами. Определить модель и загрузить в нее веса, с использованием *model.load_weights()*. Или tf.keras.models.load_model для автоматического создания модели и загрузки весов (мы можем так сделать т.к. при создании чекпоинтов выставили save_weights_only=False, т.е. сохранили и описание модели).

# %%
model = get_compiled_model() # define random model
loss, acc = model.evaluate(X_test, y_test)
print(f'Accuracy of random model {acc*100:.2f}%')
# Out:
# 5/5 [==============================] - 0s 2ms/step - loss: 5.3736 - accuracy: 0.6169
# Accuracy of random model 61.69%

# %%
model.load_weights('models/model_1.model/139_checkpoint_0.52.hdf5') # loading weights - model had created erlier
loss, acc = model.evaluate(X_test, y_test)
print(f'Accuracy of restored model {acc*100:.2f}%')
# Out:
# 5/5 [==============================] - 0s 2ms/step - loss: 0.5225 - accuracy: 0.7468
# Accuracy of restored model 74.68%

# %%
model = tf.keras.models.load_model('models/model_1.model/139_checkpoint_0.52.hdf5')
loss, acc = model.evaluate(X_test, y_test)
print(f'Accuracy of restored model {acc*100:.2f}%')
# Out:
# 5/5 [==============================] - 0s 2ms/step - loss: 0.5225 - accuracy: 0.7468
# Accuracy of restored model 74.68%

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 24)                216
#
#  dense_5 (Dense)             (None, 24)                600
#
#  dense_6 (Dense)             (None, 24)                600
#
#  dense_7 (Dense)             (None, 1)                 25
#
# =================================================================
# Total params: 1,441
# Trainable params: 1,441
# Non-trainable params: 0
# _________________________________________________________________

# %%
# import logging
# logging.getLogger('tensorflow').disabled = True

# %%
path = Path('models/model_2.model')
path.mkdir(exist_ok=True) 
cpt_filename = 'checkpoint_best.hdf5'
cpt_path = str(path / cpt_filename)

checkpoint = tf.keras.callbacks.ModelCheckpoint(cpt_path, monitor='val_accuracy', verbose=1, 
                                                save_best_only=True, mode='max')

model = get_compiled_model()
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=150, batch_size=64, verbose=0,
          callbacks=[checkpoint]
         )
# Out:
# Epoch 1: val_accuracy improved from -inf to 0.39610, saving model to models/model_2.model/checkpoint_best.hdf5
#
# Epoch 2: val_accuracy improved from 0.39610 to 0.53896, saving model to models/model_2.model/checkpoint_best.hdf5
#
# Epoch 3: val_accuracy improved from 0.53896 to 0.56494, saving model to models/model_2.model/checkpoint_best.hdf5
#
# Epoch 4: val_accuracy improved from 0.56494 to 0.61039, saving model to models/model_2.model/checkpoint_best.hdf5
#
# Epoch 5: val_accuracy improved from 0.61039 to 0.72078, saving model to models/model_2.model/checkpoint_best.hdf5
#
# Epoch 6: val_accuracy did not improve from 0.72078
#
# Epoch 7: val_accuracy did not improve from 0.72078
#
# Epoch 8: val_accuracy did not improve from 0.72078
#
# Epoch 9: val_accuracy did not improve from 0.72078
#
# Epoch 10: val_accuracy did not improve from 0.72078
#
# Epoch 11: val_accuracy did not improve from 0.72078
#
# Epoch 12: val_accuracy did not improve from 0.72078
#
# Epoch 13: val_accuracy did not improve from 0.72078
#
# Epoch 14: val_accuracy did not improve from 0.72078
#
# Epoch 15: val_accuracy did not improve from 0.72078
#
# Epoch 16: val_accuracy did not improve from 0.72078
#
# Epoch 17: val_accuracy did not improve from 0.72078
#
# Epoch 18: val_accuracy did not improve from 0.72078
#
# Epoch 19: val_accuracy did not improve from 0.72078
#
# Epoch 20: val_accuracy did not improve from 0.72078
#
# Epoch 21: val_accuracy did not improve from 0.72078
#
# Epoch 22: val_accuracy did not improve from 0.72078
#
# Epoch 23: val_accuracy did not improve from 0.72078
#
# Epoch 24: val_accuracy did not improve from 0.72078
#
# Epoch 25: val_accuracy did not improve from 0.72078
#
# Epoch 26: val_accuracy did not improve from 0.72078
#
# Epoch 27: val_accuracy did not improve from 0.72078
#
# Epoch 28: val_accuracy did not improve from 0.72078
#
# Epoch 29: val_accuracy did not improve from 0.72078
#
# Epoch 30: val_accuracy did not improve from 0.72078
#
# Epoch 31: val_accuracy did not improve from 0.72078
#
# Epoch 32: val_accuracy did not improve from 0.72078
#
# Epoch 33: val_accuracy did not improve from 0.72078
#
# Epoch 34: val_accuracy did not improve from 0.72078
#
# Epoch 35: val_accuracy did not improve from 0.72078
#
# Epoch 36: val_accuracy did not improve from 0.72078
#
# Epoch 37: val_accuracy did not improve from 0.72078
#
# Epoch 38: val_accuracy did not improve from 0.72078
#
# Epoch 39: val_accuracy did not improve from 0.72078
#
# Epoch 40: val_accuracy did not improve from 0.72078
#
# Epoch 41: val_accuracy did not improve from 0.72078
#
# Epoch 42: val_accuracy did not improve from 0.72078
#
# Epoch 43: val_accuracy did not improve from 0.72078
#
# Epoch 44: val_accuracy did not improve from 0.72078
#
# Epoch 45: val_accuracy did not improve from 0.72078
#
# Epoch 46: val_accuracy did not improve from 0.72078
#
# Epoch 47: val_accuracy did not improve from 0.72078
#
# Epoch 48: val_accuracy did not improve from 0.72078
#
# Epoch 49: val_accuracy did not improve from 0.72078
#
# Epoch 50: val_accuracy did not improve from 0.72078
#
# Epoch 51: val_accuracy did not improve from 0.72078
#
# Epoch 52: val_accuracy did not improve from 0.72078
#
# Epoch 53: val_accuracy did not improve from 0.72078
#
# Epoch 54: val_accuracy did not improve from 0.72078
#
# Epoch 55: val_accuracy did not improve from 0.72078
#
# Epoch 56: val_accuracy did not improve from 0.72078
#
# Epoch 57: val_accuracy did not improve from 0.72078
#
# Epoch 58: val_accuracy did not improve from 0.72078
#
# Epoch 59: val_accuracy did not improve from 0.72078
#
# Epoch 60: val_accuracy did not improve from 0.72078
#
# Epoch 61: val_accuracy did not improve from 0.72078
#
# Epoch 62: val_accuracy did not improve from 0.72078
#
# Epoch 63: val_accuracy did not improve from 0.72078
#
# Epoch 64: val_accuracy did not improve from 0.72078
#
# Epoch 65: val_accuracy did not improve from 0.72078
#
# Epoch 66: val_accuracy did not improve from 0.72078
#
# Epoch 67: val_accuracy did not improve from 0.72078
#
# Epoch 68: val_accuracy did not improve from 0.72078
#
# Epoch 69: val_accuracy did not improve from 0.72078
#
# Epoch 70: val_accuracy did not improve from 0.72078
#
# Epoch 71: val_accuracy did not improve from 0.72078
#
# Epoch 72: val_accuracy did not improve from 0.72078
#
# Epoch 73: val_accuracy did not improve from 0.72078
#
# Epoch 74: val_accuracy did not improve from 0.72078
#
# Epoch 75: val_accuracy did not improve from 0.72078
#
# Epoch 76: val_accuracy did not improve from 0.72078
#
# Epoch 77: val_accuracy did not improve from 0.72078
#
# Epoch 78: val_accuracy did not improve from 0.72078
#
# Epoch 79: val_accuracy did not improve from 0.72078
#
# Epoch 80: val_accuracy did not improve from 0.72078
#
# Epoch 81: val_accuracy did not improve from 0.72078
#
# Epoch 82: val_accuracy did not improve from 0.72078
#
# Epoch 83: val_accuracy did not improve from 0.72078
#
# Epoch 84: val_accuracy did not improve from 0.72078
#
# Epoch 85: val_accuracy did not improve from 0.72078
#
# Epoch 86: val_accuracy did not improve from 0.72078
#
# Epoch 87: val_accuracy did not improve from 0.72078
#
# Epoch 88: val_accuracy did not improve from 0.72078
#
# Epoch 89: val_accuracy did not improve from 0.72078
#
# Epoch 90: val_accuracy did not improve from 0.72078
#
# Epoch 91: val_accuracy did not improve from 0.72078
#
# Epoch 92: val_accuracy did not improve from 0.72078
#
# Epoch 93: val_accuracy did not improve from 0.72078
#
# Epoch 94: val_accuracy did not improve from 0.72078
#
# Epoch 95: val_accuracy did not improve from 0.72078
#
# Epoch 96: val_accuracy did not improve from 0.72078
#
# Epoch 97: val_accuracy did not improve from 0.72078
#
# Epoch 98: val_accuracy did not improve from 0.72078
#
# Epoch 99: val_accuracy did not improve from 0.72078
#
# Epoch 100: val_accuracy did not improve from 0.72078
#
# Epoch 101: val_accuracy did not improve from 0.72078
#
# Epoch 102: val_accuracy did not improve from 0.72078
#
# Epoch 103: val_accuracy did not improve from 0.72078
#
# Epoch 104: val_accuracy did not improve from 0.72078
#
# Epoch 105: val_accuracy did not improve from 0.72078
#
# Epoch 106: val_accuracy did not improve from 0.72078
#
# Epoch 107: val_accuracy did not improve from 0.72078
#
# Epoch 108: val_accuracy did not improve from 0.72078
#
# Epoch 109: val_accuracy did not improve from 0.72078
#
# Epoch 110: val_accuracy did not improve from 0.72078
#
# Epoch 111: val_accuracy did not improve from 0.72078
#
# Epoch 112: val_accuracy did not improve from 0.72078
#
# Epoch 113: val_accuracy did not improve from 0.72078
#
# Epoch 114: val_accuracy did not improve from 0.72078
#
# Epoch 115: val_accuracy did not improve from 0.72078
#
# Epoch 116: val_accuracy did not improve from 0.72078
#
# Epoch 117: val_accuracy did not improve from 0.72078
#
# Epoch 118: val_accuracy did not improve from 0.72078
#
# Epoch 119: val_accuracy did not improve from 0.72078
#
# Epoch 120: val_accuracy did not improve from 0.72078
#
# Epoch 121: val_accuracy did not improve from 0.72078
#
# Epoch 122: val_accuracy did not improve from 0.72078
#
# Epoch 123: val_accuracy did not improve from 0.72078
#
# Epoch 124: val_accuracy did not improve from 0.72078
#
# Epoch 125: val_accuracy did not improve from 0.72078
#
# Epoch 126: val_accuracy did not improve from 0.72078
#
# Epoch 127: val_accuracy did not improve from 0.72078
#
# Epoch 128: val_accuracy improved from 0.72078 to 0.73377, saving model to models/model_2.model/checkpoint_best.hdf5
#
# Epoch 129: val_accuracy did not improve from 0.73377
#
# Epoch 130: val_accuracy did not improve from 0.73377
#
# Epoch 131: val_accuracy did not improve from 0.73377
#
# Epoch 132: val_accuracy did not improve from 0.73377
#
# Epoch 133: val_accuracy did not improve from 0.73377
#
# Epoch 134: val_accuracy did not improve from 0.73377
#
# Epoch 135: val_accuracy did not improve from 0.73377
#
# Epoch 136: val_accuracy did not improve from 0.73377
#
# Epoch 137: val_accuracy did not improve from 0.73377
#
# Epoch 138: val_accuracy did not improve from 0.73377
#
# Epoch 139: val_accuracy did not improve from 0.73377
#
# Epoch 140: val_accuracy improved from 0.73377 to 0.74675, saving model to models/model_2.model/checkpoint_best.hdf5
#
# Epoch 141: val_accuracy did not improve from 0.74675
#
# Epoch 142: val_accuracy did not improve from 0.74675
#
# Epoch 143: val_accuracy did not improve from 0.74675
#
# Epoch 144: val_accuracy did not improve from 0.74675
#
# Epoch 145: val_accuracy did not improve from 0.74675
#
# Epoch 146: val_accuracy did not improve from 0.74675
# Epoch 147: val_accuracy did not improve from 0.74675
#
# Epoch 148: val_accuracy did not improve from 0.74675
#
# Epoch 149: val_accuracy did not improve from 0.74675
#
# Epoch 150: val_accuracy did not improve from 0.74675

# %%
! ls 'models/model_2.model/'
# Out:
# checkpoint_best.hdf5

# %%
model = tf.keras.models.load_model('models/model_2.model/checkpoint_best.hdf5')
loss, acc = model.evaluate(X_test, y_test)
print(f'Accuracy of random model {acc*100:.2f}%')
# Out:
# 5/5 [==============================] - 0s 2ms/step - loss: 0.6181 - accuracy: 0.7468
# Accuracy of random model 74.68%

# %%
# мы можем продолжить процесс обучения, обратите внимание на initial_epoch

model = tf.keras.models.load_model('models/model_2.model/checkpoint_best.hdf5')
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=300, batch_size=64, verbose=0,
          callbacks=[checkpoint], initial_epoch=150)
# Out:
# Epoch 151: val_accuracy did not improve from 0.74675
#
# Epoch 152: val_accuracy did not improve from 0.74675
#
# Epoch 153: val_accuracy did not improve from 0.74675
#
# Epoch 154: val_accuracy did not improve from 0.74675
#
# Epoch 155: val_accuracy did not improve from 0.74675
#
# Epoch 156: val_accuracy did not improve from 0.74675
#
# Epoch 157: val_accuracy did not improve from 0.74675
#
# Epoch 158: val_accuracy did not improve from 0.74675
#
# Epoch 159: val_accuracy did not improve from 0.74675
#
# Epoch 160: val_accuracy did not improve from 0.74675
#
# Epoch 161: val_accuracy did not improve from 0.74675
#
# Epoch 162: val_accuracy did not improve from 0.74675
#
# Epoch 163: val_accuracy did not improve from 0.74675
#
# Epoch 164: val_accuracy did not improve from 0.74675
#
# Epoch 165: val_accuracy did not improve from 0.74675
#
# Epoch 166: val_accuracy did not improve from 0.74675
#
# Epoch 167: val_accuracy did not improve from 0.74675
#
# Epoch 168: val_accuracy did not improve from 0.74675
#
# Epoch 169: val_accuracy did not improve from 0.74675
#
# Epoch 170: val_accuracy did not improve from 0.74675
#
# Epoch 171: val_accuracy did not improve from 0.74675
#
# Epoch 172: val_accuracy did not improve from 0.74675
#
# Epoch 173: val_accuracy did not improve from 0.74675
#
# Epoch 174: val_accuracy did not improve from 0.74675
#
# Epoch 175: val_accuracy did not improve from 0.74675
#
# Epoch 176: val_accuracy did not improve from 0.74675
#
# Epoch 177: val_accuracy did not improve from 0.74675
#
# Epoch 178: val_accuracy did not improve from 0.74675
#
# Epoch 179: val_accuracy did not improve from 0.74675
#
# Epoch 180: val_accuracy did not improve from 0.74675
#
# Epoch 181: val_accuracy did not improve from 0.74675
#
# Epoch 182: val_accuracy did not improve from 0.74675
#
# Epoch 183: val_accuracy did not improve from 0.74675
#
# Epoch 184: val_accuracy did not improve from 0.74675
#
# Epoch 185: val_accuracy did not improve from 0.74675
#
# Epoch 186: val_accuracy did not improve from 0.74675
#
# Epoch 187: val_accuracy did not improve from 0.74675
#
# Epoch 188: val_accuracy did not improve from 0.74675
#
# Epoch 189: val_accuracy did not improve from 0.74675
#
# Epoch 190: val_accuracy did not improve from 0.74675
#
# Epoch 191: val_accuracy did not improve from 0.74675
#
# Epoch 192: val_accuracy did not improve from 0.74675
#
# Epoch 193: val_accuracy improved from 0.74675 to 0.75325, saving model to models/model_2.model/checkpoint_best.hdf5
#
# Epoch 194: val_accuracy did not improve from 0.75325
#
# Epoch 195: val_accuracy did not improve from 0.75325
#
# Epoch 196: val_accuracy did not improve from 0.75325
#
# Epoch 197: val_accuracy did not improve from 0.75325
#
# Epoch 198: val_accuracy did not improve from 0.75325
#
# Epoch 199: val_accuracy did not improve from 0.75325
#
# Epoch 200: val_accuracy did not improve from 0.75325
#
# Epoch 201: val_accuracy did not improve from 0.75325
#
# Epoch 202: val_accuracy did not improve from 0.75325
#
# Epoch 203: val_accuracy did not improve from 0.75325
#
# Epoch 204: val_accuracy did not improve from 0.75325
#
# Epoch 205: val_accuracy did not improve from 0.75325
#
# Epoch 206: val_accuracy did not improve from 0.75325
#
# Epoch 207: val_accuracy did not improve from 0.75325
#
# Epoch 208: val_accuracy did not improve from 0.75325
#
# Epoch 209: val_accuracy did not improve from 0.75325
#
# Epoch 210: val_accuracy did not improve from 0.75325
#
# Epoch 211: val_accuracy did not improve from 0.75325
#
# Epoch 212: val_accuracy did not improve from 0.75325
#
# Epoch 213: val_accuracy did not improve from 0.75325
#
# Epoch 214: val_accuracy did not improve from 0.75325
#
# Epoch 215: val_accuracy improved from 0.75325 to 0.75974, saving model to models/model_2.model/checkpoint_best.hdf5
#
# Epoch 216: val_accuracy did not improve from 0.75974
#
# Epoch 217: val_accuracy did not improve from 0.75974
#
# Epoch 218: val_accuracy did not improve from 0.75974
#
# Epoch 219: val_accuracy did not improve from 0.75974
#
# Epoch 220: val_accuracy did not improve from 0.75974
#
# Epoch 221: val_accuracy did not improve from 0.75974
#
# Epoch 222: val_accuracy did not improve from 0.75974
#
# Epoch 223: val_accuracy did not improve from 0.75974
#
# Epoch 224: val_accuracy did not improve from 0.75974
#
# Epoch 225: val_accuracy did not improve from 0.75974
#
# Epoch 226: val_accuracy did not improve from 0.75974
#
# Epoch 227: val_accuracy did not improve from 0.75974
#
# Epoch 228: val_accuracy did not improve from 0.75974
#
# Epoch 229: val_accuracy did not improve from 0.75974
#
# Epoch 230: val_accuracy did not improve from 0.75974
#
# Epoch 231: val_accuracy did not improve from 0.75974
#
# Epoch 232: val_accuracy did not improve from 0.75974
#
# Epoch 233: val_accuracy did not improve from 0.75974
#
# Epoch 234: val_accuracy did not improve from 0.75974
#
# Epoch 235: val_accuracy did not improve from 0.75974
#
# Epoch 236: val_accuracy did not improve from 0.75974
#
# Epoch 237: val_accuracy did not improve from 0.75974
#
# Epoch 238: val_accuracy did not improve from 0.75974
#
# Epoch 239: val_accuracy did not improve from 0.75974
#
# Epoch 240: val_accuracy did not improve from 0.75974
#
# Epoch 241: val_accuracy did not improve from 0.75974
#
# Epoch 242: val_accuracy did not improve from 0.75974
#
# Epoch 243: val_accuracy did not improve from 0.75974
#
# Epoch 244: val_accuracy did not improve from 0.75974
#
# Epoch 245: val_accuracy did not improve from 0.75974
#
# Epoch 246: val_accuracy did not improve from 0.75974
#
# Epoch 247: val_accuracy did not improve from 0.75974
#
# Epoch 248: val_accuracy did not improve from 0.75974
#
# Epoch 249: val_accuracy did not improve from 0.75974
#
# Epoch 250: val_accuracy did not improve from 0.75974
#
# Epoch 251: val_accuracy did not improve from 0.75974
#
# Epoch 252: val_accuracy did not improve from 0.75974
#
# Epoch 253: val_accuracy did not improve from 0.75974
#
# Epoch 254: val_accuracy did not improve from 0.75974
#
# Epoch 255: val_accuracy did not improve from 0.75974
#
# Epoch 256: val_accuracy did not improve from 0.75974
#
# Epoch 257: val_accuracy did not improve from 0.75974
#
# Epoch 258: val_accuracy did not improve from 0.75974
#
# Epoch 259: val_accuracy did not improve from 0.75974
#
# Epoch 260: val_accuracy did not improve from 0.75974
#
# Epoch 261: val_accuracy did not improve from 0.75974
#
# Epoch 262: val_accuracy did not improve from 0.75974
#
# Epoch 263: val_accuracy did not improve from 0.75974
#
# Epoch 264: val_accuracy did not improve from 0.75974
#
# Epoch 265: val_accuracy did not improve from 0.75974
#
# Epoch 266: val_accuracy did not improve from 0.75974
#
# Epoch 267: val_accuracy did not improve from 0.75974
#
# Epoch 268: val_accuracy did not improve from 0.75974
#
# Epoch 269: val_accuracy did not improve from 0.75974
#
# Epoch 270: val_accuracy did not improve from 0.75974
#
# Epoch 271: val_accuracy did not improve from 0.75974
#
# Epoch 272: val_accuracy did not improve from 0.75974
#
# Epoch 273: val_accuracy did not improve from 0.75974
#
# Epoch 274: val_accuracy did not improve from 0.75974
#
# Epoch 275: val_accuracy did not improve from 0.75974
#
# Epoch 276: val_accuracy did not improve from 0.75974
#
# Epoch 277: val_accuracy did not improve from 0.75974
#
# Epoch 278: val_accuracy did not improve from 0.75974
#
# Epoch 279: val_accuracy did not improve from 0.75974
#
# Epoch 280: val_accuracy improved from 0.75974 to 0.76623, saving model to models/model_2.model/checkpoint_best.hdf5
#
# Epoch 281: val_accuracy did not improve from 0.76623
#
# Epoch 282: val_accuracy did not improve from 0.76623
#
# Epoch 283: val_accuracy did not improve from 0.76623
#
# Epoch 284: val_accuracy did not improve from 0.76623
#
# Epoch 285: val_accuracy did not improve from 0.76623
#
# Epoch 286: val_accuracy did not improve from 0.76623
#
# Epoch 287: val_accuracy did not improve from 0.76623
#
# Epoch 288: val_accuracy did not improve from 0.76623
#
# Epoch 289: val_accuracy did not improve from 0.76623
#
# Epoch 290: val_accuracy did not improve from 0.76623
#
# Epoch 291: val_accuracy did not improve from 0.76623
#
# Epoch 292: val_accuracy did not improve from 0.76623
#
# Epoch 293: val_accuracy did not improve from 0.76623
#
# Epoch 294: val_accuracy did not improve from 0.76623
#
# Epoch 295: val_accuracy did not improve from 0.76623
#
# Epoch 296: val_accuracy did not improve from 0.76623
#
# Epoch 297: val_accuracy did not improve from 0.76623
#
# Epoch 298: val_accuracy did not improve from 0.76623
#
# Epoch 299: val_accuracy did not improve from 0.76623
# Epoch 300: val_accuracy did not improve from 0.76623
